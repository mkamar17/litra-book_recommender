# %% [markdown]
# ### Imports

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Database connection

# %%
connection_string = "postgresql://postgres:Dormezzled79!@35.246.42.56:5432/postgres"
engine = create_engine(connection_string)

#testing connection
try:
    with engine.connect() as conn:
        print("✓ Connected to database successfully!")
except Exception as e:
    print(f"✗ Connection failed: {e}")
# Out:
# ✓ Connected to database successfully!

# %% [markdown]
# ### Viewing tables

# %%
tables_query = """
SELECT table_name 
FROM information_schema.tables 
WHERE table_schema = 'public'
"""

tables_df = pd.read_sql(tables_query, engine)
print("Available tables:")
print(tables_df)
# Out:
# Available tables:
#            table_name
# 0          user_roles
# 1                book
# 2            app_user
# 3         use_library
# 4     reading_session
# 5  user_book_progress

# %%
# Load books
books_df = pd.read_sql("SELECT * FROM book LIMIT 5", engine)
print(f"Total books: {pd.read_sql('SELECT COUNT(*) FROM book', engine).iloc[0,0]}")
print("\nSample books:")
print(books_df)
# Out:
# Total books: 177
#
# Sample books:
#      id          author                                          cover_url  \
# 0  4563  Lorna Dounaeva  https://books.google.com/books/content?id=Npid...
# 1  4564     Molly Black  https://books.google.com/books/content?id=aigH...
# 2  4565       Marc Horn  https://books.google.com/books/content?id=gfVC...
# 3  4566     Molly Black  https://books.google.com/books/content?id=fC4H...
# 4  4567      Ella Swift  https://books.google.com/books/content?id=PaQK...
#
#                                          description   external_id  \
# 0  The McBride Vendetta Psychological Thriller Se...  NpidDwAAQBAJ
# 1  “I binge read this book. It hooked me in and d...  aigHEQAAQBAJ
# 2  This collection of thrilling short stories, ea...  gfVCEQAAQBAJ
# 3  “I binge read this book. It hooked me in and d...  fC4HEQAAQBAJ
# 4  “Amazing. The action simply didn’t stop.” —Rea...  PaQKEQAAQBAJ
#
#                      genre        source  \
# ...

# %%
# Check use_library (favorites/saved books?)
library_df = pd.read_sql("SELECT * FROM use_library LIMIT 5", engine)
print(f"Total library entries: {pd.read_sql('SELECT COUNT(*) FROM use_library', engine).iloc[0,0]}")
print("\nSample library data:")
print(library_df)
# Out:
# Total library entries: 10
#
# Sample library data:
#    user_id  book_id
# 0        1     4663
# 1        1     4564
# 2        1     4636
# 3        1     4585
# 4        1     4568

# %%
# Check user reading progress
progress_df = pd.read_sql("SELECT * FROM user_book_progress LIMIT 5", engine)
print(f"Total progress records: {pd.read_sql('SELECT COUNT(*) FROM user_book_progress', engine).iloc[0,0]}")
print("\nSample progress data:")
print(progress_df)
# Out:
# Total progress records: 2
#
# Sample progress data:
#    id  current_page  total_pages  book_id  user_id
# 0   1            54          100     4565        1
# 1   2           106          250     4566        1
